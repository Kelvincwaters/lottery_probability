# %% [markdown]
# ### Lottery Prediction

# %% [markdown]
# import necessary libraries

# %%
import requests
import re
import json
from bs4 import BeautifulSoup as bs

# %% [markdown]
# notebook iopub_data_rate_limit extended, let's look at the raw web page data!

# %%
# get the data
r = requests.get('http://floridalottery.com/exptkt/ff.htm')

# load data into BS4
soup = bs(r.content)

contents = soup.prettify()
print(contents)

# %%
soup = bs(r.text, 'html.parser')
print(soup)

# %%
table = soup.find_all("table")

for row in table:
    td = row.find_all("tr")
    for data in td:
        cells = data.find_all("td")
        
print("There are currently " + str(len(table)) + " tables in this data set!")

# %%
# every table is the same length
length = len(table[3]) # assuming table 3 exists and their all the same length
print("each table is " + str(length) + " in length.")

# %%
# possible number of data points
data = len(table) * length
print("with a possible " + str(data) + " data points.")

# %%
# narrowing search by the font tag gets me much closer to what I need
# but still could clean up some information between the tables
# that are mostly non-numerical

for tr in soup.find_all('tr'):
    for td in tr.find_all('td'):
        for font in td.find_all('font'):
            print(font.text.strip("-"))

# %% [markdown]
# let's get all the necessary data into a dictionary object
